# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mahsa Roostaei**

# %% [markdown]
# Data Scientist

# %% [markdown]
# *I am interested in data science because data science was a way to become a detective, And because I am very curious about very different techniques in science, for me, it is exactly what I wanted.*

# %% [markdown]
# ### This program adds two numbers

# %%
num1 = 1
num2 = 6

# Add two numbers
sum = num1 + num2

# Display the sum
print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# The sum of 1 and 6 is 7

# %% [markdown]
# Try to put a blank line before...
#
# ---
#
# ...and after a horizontal rule.

# %% [markdown]
# <https://www.markdownguide.org>
# <fake@example.com>

# %% [markdown]
# ![Untitled Diagram.drawio.png](attachment:d23e80e0-2bb6-4c0e-89f4-d8acc9ab7cef.png)

# %% [markdown]
# First Header  | Second Header
# ------------- | -------------
# Content Cell  | Content Cell
# Content Cell  | Content Cell

# %% [markdown]
# 1. First item
# 2. Second item
# 3. Third item
# 4. Fourth item

# %% [markdown]
# - First item
# - Second item
# - Third item
# - Fourth item

# %% [markdown]
# At the command prompt, type `nano`.
